# %% [markdown]
# <h1>Data Science Tools and Ecosystem</h1>

# %% [markdown]
# <h2>Author</h2>
# Allen Wolfe

# %% [markdown]
# In this notebook, the tools of Data Science and Ecosystem will be summarized

# %% [markdown]
# <b>Objectives</b>
# <ul>
#     <li>Popular Data Science Programming Languages</li>
#     <li>Commonly Used Data Science Libraries</li>
#     <li>Open Source Data Science Tools</li>
#     <li>Programming in Python Using Jupyter Notebook</li>
# </ul>

# %% [markdown]
# Some popular Data Science programming languages are
# <ol>
#     <li>Python</li>
#     <li>R</li>
#     <li>SQL</li>
# </ol>

# %% [markdown]
# Some of the more commonly used data science libraries include:
# <ol>
#     <li>Pandas</li>
#     <li>Plotly</li>
#     <li>ggplot</li>
# </ol>

# %% [markdown]
# Data Science Tools
# <table>
#     <tr><td>Python</td></tr>
#     <tr><td>Jupyter Lab</td></tr>
#     <tr><td>GitHub</td></tr>
# </table>

# %% [markdown]
# <h3>Here are a few examples of preforming arithmatic in python:</h3>

# %%
(3*4)+5
#this is a simple expression that multiplies then adds integers
# Out:
# 17

# %%
#this line of code will convert minutes to hours by dividing by 60
minutePerHour = 60
minutes = 200
hours = minutes/ minutePerHour
print(hours)
# Out:
# 3.3333333333333335
